# %%
# pip3 install -U altair vega_datasets jupyterlab --user

# %%
# !export CUDA_VISIBLE_DEVICES=3

# %%
# %run maskrcnn_train.py -j -cp 2009 -td -load /model_zoo/detection/mask_rcnn_R_50_FPN_1x_with_momentum -c /home/caishenghang/oneflow/oneflow/python/model/maskrcnn/mask_rcnn_R_50_FPN_1x.yaml -anno annotations/sample_100_instances_val2017.json -bz 2 -i 10
# Out:
# merged config from /home/caishenghang/oneflow/oneflow/python/model/maskrcnn/mask_rcnn_R_50_FPN_1x.yaml
#     iter     rank loss_rpn_box_reg  loss_objectness     loss_box_reg  loss_classifier        loss_mask
#        0        0    0.0370298177     0.0048341891     0.1041753516     1.0981098413     0.2014964819
#        1        0    0.0505369380     0.0374210291     0.3188496828     1.2087010145     0.5192899704
#        2        0    0.0303290393     0.0102399550     0.2616937757     1.0074924231     0.3843930662
#        3        0    0.0951113701     0.1274213046     0.3003095090     0.9852290154     0.3028441668
#        4        0    0.0336049721     0.0035825907     0.1958162040     0.6846076250     0.4982362092
#        5        0    0.0786830336     0.0303827133     0.1266986728     0.4893633127     0.3395439386
#        6        0    0.0198155344     0.0001184033     0.1765494347     0.4228295386     0.2770028412
#        7        0    0.0059896321     0.0000902865     0.0733133182     0.2137151212     0.2611558437
#        8        0    0.0590836778     0.2760097086     0.1177453399     0.7317069769     0.1855577230
#        9        0    0.1194533780     0.0524199232     0.2161011845     0.3614785373     0.2669248879
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
