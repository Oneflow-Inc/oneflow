# %%
# pip3 install -U altair vega_datasets jupyterlab --user

# %%
# !export CUDA_VISIBLE_DEVICES=3

# %%
# %run maskrcnn_train.py -j -cp 2009 -td -load /model_zoo/detection/R-50 -c mask_rcnn_R_50_FPN_1x.yaml -anno annotations/instances_val2017.json -bz 1 -i 10
# Out:
# merged config from mask_rcnn_R_50_FPN_1x.yaml
# /model_zoo/detection/R-50/backbone-fpn-inner4-weight/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-inner4-bias/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-layer4-weight/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-layer4-bias/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-inner_lateral3-weight/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-inner_lateral3-bias/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-layer3-weight/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-layer3-bias/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-inner_lateral2-weight/out not found, will be initialized
# /model_zoo/detection/R-50/backbone-fpn-inner_lateral2-bias/out not found, will be initialized
# ...
